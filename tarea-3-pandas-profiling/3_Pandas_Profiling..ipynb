# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip3 install -U ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 33.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 114.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 8.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import pandas_profiling
from ydata_profiling import ProfileReport
# Out:
# /tmp/ipykernel_3285/2084558506.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
ruta = '/content/drive/MyDrive/Clase4 - Laboratorio-1/Clase4 - Laboratorio'

# %% [markdown]
# ### Lectura desde archivos CSV en dataframe

# %%
cities = pd.read_csv('%s/developer_burnout_dataset_7000.csv'%ruta)
cities.head()
# Out:
#     age  experience_years  daily_work_hours  sleep_hours  caffeine_intake  \
# 0  26.0              12.0             10.33         4.45              2.0
# 1  39.0              10.0              8.62         5.77              5.0
# 2  34.0              13.0               NaN         4.03              5.0
# 3  30.0               1.0              6.85         6.47              2.0
# 4  27.0               7.0              4.24         5.80              NaN
#
#    bugs_per_day  commits_per_day  meetings_per_day  screen_time  \
# 0          11.0              4.0               1.0        15.07
# 1          15.0             11.0               5.0        13.25
# 2           2.0             18.0               9.0        11.18
# 3          15.0             26.0               1.0        11.14
# 4           9.0             17.0               7.0         8.05
#
#    exercise_hours  stress_level burnout_level
# 0            0.14         55.96        Medium
# ...

# %%
# Número de Filas
cities.describe()
# Out:
#          latitude   longitude  temperature
# count  213.000000  213.000000   213.000000
# mean    47.499906   15.374319     9.497840
# std      6.730961   13.068014     3.561231
# min     36.130000   -9.140000    -2.200000
# 25%     42.220000    5.380000     7.190000
# 50%     47.580000   16.180000     8.880000
# 75%     52.050000   25.620000    11.190000
# max     67.850000   41.930000    18.670000

# %%
# Reporte
profile = ProfileReport(cities)

# %%
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
profile.to_file(ruta + '/ciudades_ahora.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
